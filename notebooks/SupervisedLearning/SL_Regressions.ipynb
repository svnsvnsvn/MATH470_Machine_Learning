# %%
# Week 3 1/27/25

# %% [markdown]
# # Supervised Learning Regression Models

# %%
X, y = mglearn.datasets.load_extended_boston()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression().fit(X_train, y_train)

print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.95
# Test set score: 0.61

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge = Ridge().fit(X_train, y_train)

print("Training set score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# Training set score: 0.89
# Test set score: 0.75

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# Data  Preprocessing

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
from preamble import *
import mglearn
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
dataset = pd.read_csv("../data/Position_Salaries.csv")

# %%
dataset
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = dataset.iloc[:,1:2].values
y = dataset.iloc[:,2].values

# %%
plt.scatter(X,y)
plt.title("Position vs Salary")
plt.xlabel("Position")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = "red")
plt.plot(X, lin_reg.predict(X), color = "blue")
plt.title("Linear Regression - Position vs Salary")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
accuracy = lin_reg.score(X,y)
print('Accuracy of the model is', accuracy * 100,'%')
# Out:
# Accuracy of the model is 66.90412331929895 %

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree= 4)
x_poly = poly_reg.fit_transform(X)

# %%
x_poly
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01, 8.100e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01, 2.560e+02],
#        [1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02, 6.250e+02],
#        [1.000e+00, 6.000e+00, 3.600e+01, 2.160e+02, 1.296e+03],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02, 2.401e+03],
#        [1.000e+00, 8.000e+00, 6.400e+01, 5.120e+02, 4.096e+03],
#        [1.000e+00, 9.000e+00, 8.100e+01, 7.290e+02, 6.561e+03],
#        [1.000e+00, 1.000e+01, 1.000e+02, 1.000e+03, 1.000e+04]])

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = "red")
plt.plot(X, lin_reg2.predict(poly_reg.fit_transform(X)), color = "blue")
plt.title("Linear Regression - Position vs Salary")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()
# what even is a polynomial

# %%
accuracy2 = lin_reg2.score(poly_reg.fit_transform(X),y)
print('Accuracy of the model is', accuracy2 * 100,'%')
# Out:
# Accuracy of the model is 99.73922891706614 %

# %%
# Practice simulating data using rand method, then build a polynomial model 
X = np.random.uniform(-7, 7, 100)
print(X)
true_coeffs = [-3, 2, 1]
# Out:
# [ 5.01162928 -0.56766255 -4.79099227  2.68195566 -4.51476099 -1.90320011
#  -2.54979662 -5.82931368  4.72660652 -3.60660104  1.42601263 -0.53448414
#   2.93936768  6.63878861  2.34498918 -1.41996617 -6.83203503  3.43955758
#   3.36627779 -4.13088659 -2.67633102 -5.53561754 -6.83811414 -0.11258335
#  -4.31401589 -5.45125801  0.91637538  1.40421611  1.07046253  3.8964992
#  -5.26829656 -0.3260355  -3.31050136 -3.45699691 -6.27692123 -6.50630666
#  -4.86569792 -4.80752737 -3.1732552   5.65677874  4.23282742 -4.36294906
#  -2.49439414  6.93021513  1.91018463  3.54493827 -6.68901557  5.01245245
#   0.42539214  2.30655993 -5.32584313  0.20866177 -0.11134621 -6.45740216
#  -1.75471556  0.87519234  0.50683231 -0.11085047 -5.04602968  6.5972443
#  -4.50629778  6.76470644  1.61000978  3.87850155 -2.99047407  4.43252448
#   3.80682156 -2.53639736  3.30786304  0.21874776  0.71598535  3.32649683
#   6.41574335 -4.45934122 -5.12992491  5.00819344 -3.52232024 -5.45559969
#   2.90785019 -6.63591003  0.56443294 -2.77638919 -1.94634768  0.54598416
#   4.34606371  2.95356586 -0.50074259  1.61008179 -2.07050412  6.95824133
#  -6.16860432  5.2670696   6.24997024 -5.78771909  2.31344491 -4.59950679
#   6.2374934  -2.74823006  3.36410598  4.08204227]
